# %%
import requests
from bs4 import BeautifulSoup
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
api = os.getenv('API')

# %%
url = "https://content.guardianapis.com/technology/artificialintelligenceai?&api-key="+ api + "&type=article&page=1"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
x=response.json()

# %%
x
# Out:
# {'response': {'status': 'ok',
#   'userTier': 'developer',
#   'total': 4512,
#   'startIndex': 1,
#   'pageSize': 10,
#   'currentPage': 1,
#   'pages': 452,
#   'orderBy': 'newest',
#   'tag': {'id': 'technology/artificialintelligenceai',
#    'type': 'keyword',
#    'sectionId': 'technology',
#    'sectionName': 'Technology',
#    'webTitle': 'AI (artificial intelligence)',
#    'webUrl': 'https://www.theguardian.com/technology/artificialintelligenceai',
#    'apiUrl': 'https://content.guardianapis.com/technology/artificialintelligenceai',
#    'keywordType': 'other'},
#   'results': [{'id': 'environment/2026/jun/16/ai-could-help-win-race-against-extinction-of-vital-plants-say-botanists',
#     'type': 'article',
#     'sectionId': 'environment',
#     'sectionName': 'Environment',
#     'webPublicationDate': '2026-06-16T06:00:48Z',
#     'webTitle': 'AI could help win ‘race against extinction’ of vital plants, say botanists',
#     'webUrl': 'https://www.theguardian.com/environment/2026/jun/16/ai-could-help-win-race-against-extinction-of-vital-plants-say-botanists',
#     'apiUrl': 'https://content.guardianapis.com/environment/2026/jun/16/ai-could-help-win-race-against-extinction-of-vital-plants-say-botanists',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2026/jun/15/ai-use-by-the-us-government-is-ballooning-and-the-lack-of-transparency-is-troubling',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2026-06-15T12:00:25Z',
#     'webTitle': 'AI use by the US government is ballooning. And the lack of transparency is troubling | Nathan E Sanders and Bruce Schneier',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2026/jun/15/ai-use-by-the-us-government-is-ballooning-and-the-lack-of-transparency-is-troubling',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2026/jun/15/ai-use-by-the-us-government-is-ballooning-and-the-lack-of-transparency-is-troubling',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'australia-news/2026/jun/15/andrew-hastie-ai-artificial-intelligence-power-cold-war-nuclear-arms-race-comparison-australia',
#     'type': 'article',
#     'sectionId': 'australia-news',
#     'sectionName': 'Australia news',
#     'webPublicationDate': '2026-06-15T08:30:07Z',
#     'webTitle': 'Andrew Hastie compares AI to cold-war nuclear arms race and warns Australia may fall behind',
#     'webUrl': 'https://www.theguardian.com/australia-news/2026/jun/15/andrew-hastie-ai-artificial-intelligence-power-cold-war-nuclear-arms-race-comparison-australia',
#     'apiUrl': 'https://content.guardianapis.com/australia-news/2026/jun/15/andrew-hastie-ai-artificial-intelligence-power-cold-war-nuclear-arms-race-comparison-australia',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2026/jun/15/europe-us-big-tech-silicon-valley-european-commission',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2026-06-15T04:00:03Z',
#     'webTitle': 'Europe is starting to break up with US big tech. But it’s still abiding by the Silicon Valley rulebook | Max von Thun',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2026/jun/15/europe-us-big-tech-silicon-valley-european-commission',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2026/jun/15/europe-us-big-tech-silicon-valley-european-commission',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'commentisfree/2026/jun/12/scientists-headphones-block-annoying-noises',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2026-06-14T13:04:37Z',
#     'webTitle': 'Scientists are working on headphones that block annoying noises and allow the ones you love? I can’t wait! | Emma Beddington',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2026/jun/12/scientists-headphones-block-annoying-noises',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2026/jun/12/scientists-headphones-block-annoying-noises',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'business/2026/jun/14/ai-technology-workplace-boundaries-elon-musk',
#     'type': 'article',
#     'sectionId': 'business',
#     'sectionName': 'Business',
#     'webPublicationDate': '2026-06-14T11:03:07Z',
#     'webTitle': 'Elon Musk and co may relish march of the robots but there must be AI boundaries in the workplace | Heather Stewart',
#     'webUrl': 'https://www.theguardian.com/business/2026/jun/14/ai-technology-workplace-boundaries-elon-musk',
#     'apiUrl': 'https://content.guardianapis.com/business/2026/jun/14/ai-technology-workplace-boundaries-elon-musk',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'media/2026/jun/14/have-i-been-influenced-personal-taste-out-of-fashion-algorithm',
#     'type': 'article',
#     'sectionId': 'media',
#     'sectionName': 'Media',
#     'webPublicationDate': '2026-06-14T11:00:42Z',
#     'webTitle': '‘Have I been influenced, or is this actually me?’ How personal taste fell out of fashion',
#     'webUrl': 'https://www.theguardian.com/media/2026/jun/14/have-i-been-influenced-personal-taste-out-of-fashion-algorithm',
#     'apiUrl': 'https://content.guardianapis.com/media/2026/jun/14/have-i-been-influenced-personal-taste-out-of-fashion-algorithm',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'commentisfree/2026/jun/13/momfluencers-ai-co-parenting',
#     'type': 'article',
#     'sectionId': 'commentisfree',
#     'sectionName': 'Opinion',
#     'webPublicationDate': '2026-06-13T12:00:13Z',
#     'webTitle': 'Momfluencers are co-parenting with AI. Is it better than a man? | Arwa Mahdawi',
#     'webUrl': 'https://www.theguardian.com/commentisfree/2026/jun/13/momfluencers-ai-co-parenting',
#     'apiUrl': 'https://content.guardianapis.com/commentisfree/2026/jun/13/momfluencers-ai-co-parenting',
#     'isHosted': False,
#     'pillarId': 'pillar/opinion',
#     'pillarName': 'Opinion'},
#    {'id': 'society/2026/jun/13/nerve-lab-uk-ai-brain-scanning-tech-childrens-screen-time',
#     'type': 'article',
#     'sectionId': 'society',
#     'sectionName': 'Society',
#     'webPublicationDate': '2026-06-13T11:00:13Z',
#     'webTitle': 'Pioneering UK Nerve Lab harnesses AI to map effect of children’s screen time ',
#     'webUrl': 'https://www.theguardian.com/society/2026/jun/13/nerve-lab-uk-ai-brain-scanning-tech-childrens-screen-time',
#     'apiUrl': 'https://content.guardianapis.com/society/2026/jun/13/nerve-lab-uk-ai-brain-scanning-tech-childrens-screen-time',
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'film/2026/jun/13/beeban-kidron-interview-baroness-big-tech-online-child-abuse',
#     'type': 'article',
#     'sectionId': 'film',
#     'sectionName': 'Film',
#     'webPublicationDate': '2026-06-13T10:58:12Z',
#     'webTitle': '‘Why would you put a toxic product into the hands of a young child?’: director turned activist Beeban Kidron on why big tech needs its ‘tobacco moment’',
#     'webUrl': 'https://www.theguardian.com/film/2026/jun/13/beeban-kidron-interview-baroness-big-tech-online-child-abuse',
#     'apiUrl': 'https://content.guardianapis.com/film/2026/jun/13/beeban-kidron-interview-baroness-big-tech-online-child-abuse',
#     'isHosted': False,
#     'pillarId': 'pillar/arts',
#     'pillarName': 'Arts'}],
#   'leadContent': [{'id': 'technology/2026/jun/13/anthropic-disable-advanced-ai-models-us-government-order',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-13T12:37:12Z',
#     'webTitle': 'Anthropic to disable its most advanced AI models after US order limiting foreign access',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/13/anthropic-disable-advanced-ai-models-us-government-order',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/13/anthropic-disable-advanced-ai-models-us-government-order',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/13/uk-ai-hardware-london-tech-week-investment-chips',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-13T11:01:12Z',
#     'webTitle': 'UK sets out AI infrastructure push at London Tech Week – how does it stack up?',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/13/uk-ai-hardware-london-tech-week-investment-chips',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/13/uk-ai-hardware-london-tech-week-investment-chips',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/12/police-officer-under-criminal-investigation-over-alleged-use-of-ai',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-12T20:12:51Z',
#     'webTitle': 'Derbyshire police officer investigated over AI-generated ‘evidential material’',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/12/police-officer-under-criminal-investigation-over-alleged-use-of-ai',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/12/police-officer-under-criminal-investigation-over-alleged-use-of-ai',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/09/anthropic-claude-mythos-ai-model',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-09T22:28:29Z',
#     'webTitle': 'Anthropic releases ‘safe’ version of Claude Mythos AI model to public',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/09/anthropic-claude-mythos-ai-model',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/09/anthropic-claude-mythos-ai-model',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/09/ai-legal-assistants-england-wales-cannot-replace-funding-staff',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-08T23:01:38Z',
#     'webTitle': 'Plan for AI legal assistants in England and Wales ‘cannot replace funding and staff’, lawyers say',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/09/ai-legal-assistants-england-wales-cannot-replace-funding-staff',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/09/ai-legal-assistants-england-wales-cannot-replace-funding-staff',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/08/anti-slop-ai-art',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-08T13:00:25Z',
#     'webTitle': 'Artists are making ‘anti-slop’ to rebel against AI: ‘It’s been rammed down our throats’',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/08/anti-slop-ai-art',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/08/anti-slop-ai-art',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/07/billions-spent-hypothetical-returns-the-ai-boom-explained-with-six-charts',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-07T11:00:31Z',
#     'webTitle': 'Billions spent and hypothetical returns: the AI boom explained with six charts',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/07/billions-spent-hypothetical-returns-the-ai-boom-explained-with-six-charts',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/07/billions-spent-hypothetical-returns-the-ai-boom-explained-with-six-charts',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/07/anti-ai-tech-extremism-violence',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-07T10:00:31Z',
#     'webTitle': '‘A driver of political violence’: how the breakneck AI boom is fueling anti-tech extremism',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/07/anti-ai-tech-extremism-violence',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/07/anti-ai-tech-extremism-violence',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/05/labour-will-make-ai-work-for-workers-liz-kendall',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-05T17:00:04Z',
#     'webTitle': 'Labour will make AI ‘work for the workers’, says Liz Kendall ',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/05/labour-will-make-ai-work-for-workers-liz-kendall',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/05/labour-will-make-ai-work-for-workers-liz-kendall',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'},
#    {'id': 'technology/2026/jun/05/anthropic-urges-temporary-pause-on-ai-development-to-discuss-risks',
#     'type': 'article',
#     'sectionId': 'technology',
#     'sectionName': 'Technology',
#     'webPublicationDate': '2026-06-05T15:35:24Z',
#     'webTitle': 'Anthropic says the world should have option to ‘pause’ on AI',
#     'webUrl': 'https://www.theguardian.com/technology/2026/jun/05/anthropic-urges-temporary-pause-on-ai-development-to-discuss-risks',
#     'apiUrl': 'https://content.guardianapis.com/technology/2026/jun/05/anthropic-urges-temporary-pause-on-ai-development-to-discuss-risks',
#     'tags': [],
#     'references': [],
#     'isHosted': False,
#     'pillarId': 'pillar/news',
#     'pillarName': 'News'}]}}

# %%
web_urls = [item['webUrl'] for item in x['response']['results']][1:5]

for url in web_urls:
    print(url)
    print("\n")
# Out:
# https://www.theguardian.com/commentisfree/2026/jun/15/ai-use-by-the-us-government-is-ballooning-and-the-lack-of-transparency-is-troubling
#
#
# https://www.theguardian.com/australia-news/2026/jun/15/andrew-hastie-ai-artificial-intelligence-power-cold-war-nuclear-arms-race-comparison-australia
#
#
# https://www.theguardian.com/commentisfree/2026/jun/15/europe-us-big-tech-silicon-valley-european-commission
#
#
# https://www.theguardian.com/commentisfree/2026/jun/12/scientists-headphones-block-annoying-noises

# %%
from datetime import datetime

# Create a folder with the current date and time format
current_datetime = datetime.now()
folder_name = current_datetime.strftime('%H_%M_%d_%m_%Y')

if not os.path.exists(folder_name):
    os.makedirs(folder_name)

# %%
def save_content_to_file(url, folder, filename):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
 
            with open(os.path.join(folder, filename), 'w', encoding='utf-8') as file:
                for header in soup.find_all(['h1']):
                    file.write("Tile: " + header.text + '\n'*5)
                for paragraph in soup.find_all('p'):
                    file.write(paragraph.text + '\n')
        else:
            print("Failed to retrieve the page:", url)
    except Exception as e:
        print("An error occurred:", e)

# Loop through the list of web URLs and save content to separate text files
for index, url in enumerate(web_urls):
    filename = f'article_{index}.txt'  # Create a unique filename for each article
    save_content_to_file(url, folder_name, filename)

print("Executed Perfectly")
# Out:
# Executed Perfectly
